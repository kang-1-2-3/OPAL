# %%
from av2.datasets.sensor.sensor_dataloader import SensorDataloader
from pathlib import Path

dataset_path = "/home/kang/dataset/av2"
dataset_path = Path(dataset_path)
# 创建数据加载器实例
dataloader = SensorDataloader(dataset_path, with_cache=False)
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
print(dataloader)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 print(dataloader.populate_lidar_records())
#
# File /opt/conda/lib/python3.10/site-packages/av2/datasets/sensor/sensor_dataloader.py:246, in SensorDataloader.populate_lidar_records(self)
#     238 def populate_lidar_records(self) -> pd.DataFrame:
#     239     """Obtain (log_id, sensor_name, timestamp_ns) 3-tuples for all LiDAR sweeps in the dataset.
#     240
#     241     Returns:
#    (...)
#     244             should be populated with `lidar` in every entry.
#     245     """
# --> 246     lidar_paths = sorted(self.dataset_dir.glob(LIDAR_PATTERN), key=lambda x: int(x.stem))
#     247     lidar_record_list = [
#     248         convert_path_to_named_record(x) for x in track(lidar_paths, description="Loading lidar records ...")
#     249     ]
# ...

# %%
print(len(dataloader))
# Out:
# 157192
